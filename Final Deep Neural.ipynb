# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# Import our input dataset
spotifydf = pd.read_csv(r'C:\Users\Surface\Desktop\Class\Final\archive (2)\spotify_dataset.csv')
spotifydf.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1         0.417   0.620    3    -7.727
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX         0.498   0.505    3   -12.475
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh         0.657   0.649    5   -13.392
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv         0.590   0.545    7   -12.058
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx         0.515   0.765   11    -3.515
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0403         0.490          0.000000    0.0779    0.845
# 1     1       0.0337         0.018          0.107000    0.1760    0.797
# ...

# %%
# Generate our categorical variable list
spotifydf_cat = spotifydf.dtypes[spotifydf.dtypes == "object"].index.tolist()

# %%
# Check the number of unique values in each column
spotifydf[spotifydf_cat].nunique()
# Out:
# track     35853
# artist    11902
# uri       40553
# decade        6
# dtype: int64

# %%
# Create a OneHotEncoder instance
#enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
#encode_df = pd.DataFrame(enc.fit_transform(attrition_df[attrition_cat]))

# Add the encoded variable names to the DataFrame
#encode_df.columns = enc.get_feature_names(attrition_cat)
#encode_df.head()

# %%
cleandf = spotifydf.drop(columns=["uri", "artist", "track"])
cleandf
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.417   0.620    3    -7.727     1       0.0403        0.4900
# 1             0.498   0.505    3   -12.475     1       0.0337        0.0180
# 2             0.657   0.649    5   -13.392     1       0.0380        0.8460
# 3             0.590   0.545    7   -12.058     0       0.1040        0.7060
# 4             0.515   0.765   11    -3.515     0       0.1240        0.8570
# ...             ...     ...  ...       ...   ...          ...           ...
# 41094         0.172   0.358    9   -14.430     1       0.0342        0.8860
# 41095         0.910   0.366    1    -9.954     1       0.0941        0.0996
# 41096         0.719   0.804   10    -4.581     1       0.0355        0.0132
# 41097         0.600   0.177    7   -16.070     1       0.0561        0.9890
# 41098         0.121   0.123    4   -23.025     0       0.0443        0.9640
#
# ...

# %%
#Change Decades
cleandf["decade"].replace({"60s":1960, "10s":2010, "20s":2020, "30s":1930, "40s":1940, "50s":1950, "70s":1970, "80s":1980, "90s":1990, "00s": 2000}, inplace = True)
cleandf
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.417   0.620    3    -7.727     1       0.0403        0.4900
# 1             0.498   0.505    3   -12.475     1       0.0337        0.0180
# 2             0.657   0.649    5   -13.392     1       0.0380        0.8460
# 3             0.590   0.545    7   -12.058     0       0.1040        0.7060
# 4             0.515   0.765   11    -3.515     0       0.1240        0.8570
# ...             ...     ...  ...       ...   ...          ...           ...
# 41094         0.172   0.358    9   -14.430     1       0.0342        0.8860
# 41095         0.910   0.366    1    -9.954     1       0.0941        0.0996
# 41096         0.719   0.804   10    -4.581     1       0.0355        0.0132
# 41097         0.600   0.177    7   -16.070     1       0.0561        0.9890
# 41098         0.121   0.123    4   -23.025     0       0.0443        0.9640
#
# ...

# %%
# Remove Popularity outcome target from features data
y = cleandf.popularity
X = cleandf.drop(columns="popularity")

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the StandardScaler
X_scaler = scaler.fit(cleandf)

# %%
# Scale the data
scaled_data = scaler.transform(cleandf)

# %%
# Create a DataFrame with the scaled data
#transformed_scaled_data = pd.DataFrame(scaled_data, columns=cleandf.columns)
#transformed_scaled_data.head()

# %%
# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# C:\Users\Surface\anaconda3\envs\PythonData\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - popularity
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15944/1945474224.py in <module>
#       1 # Scale the data
# ----> 2 X_train_scaled = X_scaler.transform(X_train)
#       3 X_test_scaled = X_scaler.transform(X_test)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X, copy)
#     978             estimator=self,
#     979             dtype=FLOAT_DTYPES,
# --> 980             force_all_finite="allow-nan",
#     981         )
#     982
#
# ...
