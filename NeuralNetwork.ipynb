# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# %%
spotifydf = pd.read_csv("spotify_dataset.csv")
spotifydf
# Out:
#                        track            artist  \
# 0      Jealous Kind Of Fella     Garland Green
# 1              Initials B.B.  Serge Gainsbourg
# 2               Melody Twist       Lord Melody
# 3              Mi Bomba Sonó        Celia Cruz
# 4                Uravu Solla       P. Susheela
# ...                      ...               ...
# 41094          Lotus Flowers             Yolta
# 41095      Calling My Spirit       Kodak Black
# 41096          Teenage Dream        Katy Perry
# 41097         Stormy Weather    Oscar Peterson
# 41098                   Dust       Hans Zimmer
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:1dtKN6wwlolkM8XZy2y9C1         0.417   0.620    3
# 1      spotify:track:5hjsmSnUefdUqzsDogisiX         0.498   0.505    3
# 2      spotify:track:6uk8tI6pwxxdVTNlNOJeJh         0.657   0.649    5
# 3      spotify:track:7aNjMJ05FvUXACPWZ7yJmv         0.590   0.545    7
# ...

# %%
# Generate our categorical variable list
spotifydf_cat = spotifydf.dtypes[spotifydf.dtypes == "object"].index.tolist()

# %%
# Check the number of unique values in each column
spotifydf[spotifydf_cat].nunique()
# Out:
# track     35853
# artist    11902
# uri       40553
# decade        6
# dtype: int64

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# %%
help(OneHotEncoder)
# Out:
# Help on class OneHotEncoder in module sklearn.preprocessing._encoders:
#
# class OneHotEncoder(_BaseEncoder)
#  |  OneHotEncoder(*, categories='auto', drop=None, sparse=True, dtype=<class 'numpy.float64'>, handle_unknown='error')
#  |
#  |  Encode categorical features as a one-hot numeric array.
#  |
#  |  The input to this transformer should be an array-like of integers or
#  |  strings, denoting the values taken on by categorical (discrete) features.
#  |  The features are encoded using a one-hot (aka 'one-of-K' or 'dummy')
#  |  encoding scheme. This creates a binary column for each category and
#  |  returns a sparse matrix or dense array (depending on the ``sparse``
#  |  parameter)
#  |
#  |  By default, the encoder derives the categories based on the unique values
#  |  in each feature. Alternatively, you can also specify the `categories`
#  |  manually.
#  |
#  |  This encoding is needed for feeding categorical data to many scikit-learn
# ...

# %%
cleandf = spotifydf.drop(columns=["uri", "artist", "track"])
cleandf
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.417   0.620    3    -7.727     1       0.0403        0.4900
# 1             0.498   0.505    3   -12.475     1       0.0337        0.0180
# 2             0.657   0.649    5   -13.392     1       0.0380        0.8460
# 3             0.590   0.545    7   -12.058     0       0.1040        0.7060
# 4             0.515   0.765   11    -3.515     0       0.1240        0.8570
# ...             ...     ...  ...       ...   ...          ...           ...
# 41094         0.172   0.358    9   -14.430     1       0.0342        0.8860
# 41095         0.910   0.366    1    -9.954     1       0.0941        0.0996
# 41096         0.719   0.804   10    -4.581     1       0.0355        0.0132
# 41097         0.600   0.177    7   -16.070     1       0.0561        0.9890
# 41098         0.121   0.123    4   -23.025     0       0.0443        0.9640
#
# ...

# %%
cleandf2 = cleandf.to_numpy()

# %%
cleandf2.reshape(-1, 1)
# Out:
# array([[0.417],
#        [0.62],
#        [3],
#        ...,
#        [15],
#        [0],
#        ['10s']], dtype=object)

# %%
# Fit and transform the OneHotEncoder using the categorical variable list
encode_array = enc.fit_transform(cleandf)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6912/2192548431.py in <module>
#       1 # Fit and transform the OneHotEncoder using the categorical variable list
# ----> 2 encode_array = enc.fit_transform(cleandf)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     449         """
#     450         self._validate_keywords()
# --> 451         return super().fit_transform(X, y)
#     452
#     453     def transform(self, X):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
# ...

# %%
# Add the encoded variable names to the DataFrame
encode_df.columns = enc.get_feature_names(spotifydf_cat)
encode_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6912/3354694437.py in <module>
#       1 # Add the encoded variable names to the DataFrame
# ----> 2 encode_df.columns = enc.get_feature_names(spotifydf_cat)
#       3 encode_df.head()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\preprocessing\_encoders.py in get_feature_names(self, input_features)
#     634                 "input_features should have length equal to number of "
#     635                 "features ({}), got {}".format(len(self.categories_),
# --> 636                                                len(input_features)))
#     637
#     638         feature_names = []
#
# ValueError: input_features should have length equal to number of features (17), got 4
