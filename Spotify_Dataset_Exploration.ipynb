# 25%        0.330000     97.395500  1.729165e+05        4.000000     27.599510
# 50%        0.559000    117.564000  2.179070e+05        4.000000     35.850270
# 75%        0.768000    136.492000  2.667730e+05        4.000000     47.627240
# max        0.996000    241.423000  4.170227e+06        5.000000    433.182000
#
#            sections    popularity
# count  41099.000000  41099.000000
# mean      10.475632      0.499964
# std        4.872026      0.500006
# min        0.000000      0.000000
# 25%        8.000000      0.000000
# 50%       10.000000      0.000000
# 75%       12.000000      1.000000
# max      169.000000      1.000000

# %%
data.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1         0.417   0.620    3    -7.727
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX         0.498   0.505    3   -12.475
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh         0.657   0.649    5   -13.392
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv         0.590   0.545    7   -12.058
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx         0.515   0.765   11    -3.515
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0403         0.490          0.000000    0.0779    0.845
# 1     1       0.0337         0.018          0.107000    0.1760    0.797
# 2     1       0.0380         0.846          0.000004    0.1190    0.908
# 3     0       0.1040         0.706          0.024600    0.0610    0.967
# 4     0       0.1240         0.857          0.000872    0.2130    0.906
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  popularity  \
# 0  185.655       173533               3    32.94975         9           1
# 1  101.801       213613               4    48.82510        10           0
# 2  115.940       223960               4    37.22663        12           0
# 3  105.592       157907               4    24.75484         8           0
# 4  114.617       245600               4    21.79874        14           0
#
#   decade
# 0    60s
# 1    60s
# 2    60s
# 3    60s
# 4    60s

# %%
data.dtypes
# Out:
# track                object
# artist               object
# uri                  object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# chorus_hit          float64
# sections              int64
# popularity            int64
# decade               object
# dtype: object

# %% [markdown]
# # Visualizations

# %%
import seaborn as sns
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np

# %%
data_plot = data.select_dtypes(include=[np.number]).dropna()

# %% [markdown]
# # Correlation matrix

# %%
# Normalize values before calculating correlation matrix
from sklearn.preprocessing import Normalizer
normalized = Normalizer().fit_transform(data_plot)

norm_df = pd.DataFrame(normalized)
norm_df.columns = data_plot.columns
norm_corr = norm_df.corr()

norm_corr
# Out:
#                   danceability    energy       key  loudness      mode  \
# danceability          1.000000  0.468483  0.394194 -0.495813  0.438483
# energy                0.468483  1.000000  0.298241 -0.019581  0.303140
# key                   0.394194  0.298241  1.000000 -0.418290  0.232375
# loudness             -0.495813 -0.019581 -0.418290  1.000000 -0.431590
# mode                  0.438483  0.303140  0.232375 -0.431590  1.000000
# speechiness           0.435437  0.235325  0.235862 -0.338443  0.192633
# acousticness          0.442661 -0.058521  0.333814 -0.754872  0.420066
# instrumentalness      0.221895  0.143792  0.249049 -0.557096  0.215593
# liveness              0.328264  0.429364  0.271989 -0.334844  0.320411
# valence               0.732040  0.548667  0.323653 -0.282941  0.389219
# tempo                 0.620919  0.569850  0.459528 -0.595988  0.514454
# duration_ms          -0.511204 -0.453764 -0.390454  0.553536 -0.424857
# time_signature        0.745911  0.563192  0.499136 -0.699032  0.554609
# chorus_hit            0.286779  0.223439  0.231858 -0.274585  0.234895
# sections              0.270920  0.152369  0.177834 -0.262862  0.225423
# popularity            0.211119  0.141414  0.028885  0.134045  0.105047
#
#                   speechiness  acousticness  instrumentalness  liveness  \
# danceability         0.435437      0.442661          0.221895  0.328264
# energy               0.235325     -0.058521          0.143792  0.429364
# key                  0.235862      0.333814          0.249049  0.271989
# loudness            -0.338443     -0.754872         -0.557096 -0.334844
# mode                 0.192633      0.420066          0.215593  0.320411
# speechiness          1.000000      0.265278          0.066356  0.337440
# acousticness         0.265278      1.000000          0.435663  0.316855
# instrumentalness     0.066356      0.435663          1.000000  0.181602
# liveness             0.337440      0.316855          0.181602  1.000000
# valence              0.234369      0.284129          0.081780  0.307111
# tempo                0.367197      0.503618          0.394953  0.459816
# duration_ms         -0.385976     -0.443112         -0.407857 -0.422079
# time_signature       0.392202      0.605023          0.453229  0.517831
# chorus_hit           0.119193      0.270165          0.146904  0.213748
# sections             0.085448      0.265693          0.102627  0.154966
# popularity          -0.045845     -0.094134         -0.272766 -0.007757
#
#                    valence     tempo  duration_ms  time_signature  chorus_hit  \
# danceability      0.732040  0.620919    -0.511204        0.745911    0.286779
# energy            0.548667  0.569850    -0.453764        0.563192    0.223439
# key               0.323653  0.459528    -0.390454        0.499136    0.231858
# loudness         -0.282941 -0.595988     0.553536       -0.699032   -0.274585
# mode              0.389219  0.514454    -0.424857        0.554609    0.234895
# speechiness       0.234369  0.367197    -0.385976        0.392202    0.119193
# acousticness      0.284129  0.503618    -0.443112        0.605023    0.270165
# instrumentalness  0.081780  0.394953    -0.407857        0.453229    0.146904
# liveness          0.307111  0.459816    -0.422079        0.517831    0.213748
# valence           1.000000  0.576170    -0.400793        0.603364    0.285249
# tempo             0.576170  1.000000    -0.823127        0.820874    0.322858
# duration_ms      -0.400793 -0.823127     1.000000       -0.708693   -0.169353
# time_signature    0.603364  0.820874    -0.708693        1.000000    0.371296
# chorus_hit        0.285249  0.322858    -0.169353        0.371296    1.000000
# sections          0.280889  0.355771    -0.209034        0.324346   -0.113868
# popularity        0.229321  0.049036     0.032576        0.053509    0.039159
#
#                   sections  popularity
# danceability      0.270920    0.211119
# energy            0.152369    0.141414
# key               0.177834    0.028885
# loudness         -0.262862    0.134045
# mode              0.225423    0.105047
# speechiness       0.085448   -0.045845
# acousticness      0.265693   -0.094134
# instrumentalness  0.102627   -0.272766
# liveness          0.154966   -0.007757
# valence           0.280889    0.229321
# tempo             0.355771    0.049036
# duration_ms      -0.209034    0.032576
# time_signature    0.324346    0.053509
# chorus_hit       -0.113868    0.039159
# sections          1.000000    0.077315
# popularity        0.077315    1.000000

# %%
# Visualize Feature Correlations
def plot_corr(df,size=8):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    
    plt.xticks(rotation=50)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);

# %%
plot_corr(norm_df)
# Yellow: Positive correlation
# Blue: Negative correlation

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(norm_df, 20))
# Out:
# Top Absolute Correlations
# tempo         duration_ms         0.823127
#               time_signature      0.820874
# loudness      acousticness        0.754872
# danceability  time_signature      0.745911
#               valence             0.732040
# duration_ms   time_signature      0.708693
# loudness      time_signature      0.699032
# danceability  tempo               0.620919
# acousticness  time_signature      0.605023
# valence       time_signature      0.603364
# loudness      tempo               0.595988
# valence       tempo               0.576170
# energy        tempo               0.569850
#               time_signature      0.563192
# loudness      instrumentalness    0.557096
# mode          time_signature      0.554609
# loudness      duration_ms         0.553536
# energy        valence             0.548667
# liveness      time_signature      0.517831
# mode          tempo               0.514454
# dtype: float64

# %%
def get_top_correlations(df, n=5):
    au_corr = df.corr().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Correlations")
print(get_top_correlations(norm_df, 20))
# Out:
# Top Correlations
# tempo             time_signature    0.820874
# danceability      time_signature    0.745911
#                   valence           0.732040
#                   tempo             0.620919
# acousticness      time_signature    0.605023
# valence           time_signature    0.603364
#                   tempo             0.576170
# energy            tempo             0.569850
#                   time_signature    0.563192
# mode              time_signature    0.554609
# loudness          duration_ms       0.553536
# energy            valence           0.548667
# liveness          time_signature    0.517831
# mode              tempo             0.514454
# acousticness      tempo             0.503618
# key               time_signature    0.499136
# danceability      energy            0.468483
# liveness          tempo             0.459816
# key               tempo             0.459528
# instrumentalness  time_signature    0.453229
# dtype: float64

# %%
def get_bottom_correlations(df, n=5):
    au_corr = df.corr().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=True)
    return au_corr[0:n]

print("Bottom Correlations")
print(get_bottom_correlations(norm_df, 20))
# Out:
# Bottom Correlations
# tempo             duration_ms        -0.823127
# loudness          acousticness       -0.754872
# duration_ms       time_signature     -0.708693
# loudness          time_signature     -0.699032
#                   tempo              -0.595988
#                   instrumentalness   -0.557096
# danceability      duration_ms        -0.511204
#                   loudness           -0.495813
# energy            duration_ms        -0.453764
# acousticness      duration_ms        -0.443112
# loudness          mode               -0.431590
# mode              duration_ms        -0.424857
# liveness          duration_ms        -0.422079
# key               loudness           -0.418290
# instrumentalness  duration_ms        -0.407857
# valence           duration_ms        -0.400793
# key               duration_ms        -0.390454
# speechiness       duration_ms        -0.385976
# loudness          speechiness        -0.338443
#                   liveness           -0.334844
# dtype: float64

# %% [markdown]
# # Exploration

# %% [markdown]
# ## Plotting

# %%
df = pd.read_csv('spotify_dataset.csv', encoding="ISO-8859-1")
df.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3         Mi Bomba SonÃ³        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:1dtKN6wwlolkM8XZy2y9C1         0.417   0.620    3    -7.727
# 1  spotify:track:5hjsmSnUefdUqzsDogisiX         0.498   0.505    3   -12.475
# 2  spotify:track:6uk8tI6pwxxdVTNlNOJeJh         0.657   0.649    5   -13.392
# 3  spotify:track:7aNjMJ05FvUXACPWZ7yJmv         0.590   0.545    7   -12.058
# 4  spotify:track:1rQ0clvgkzWr001POOPJWx         0.515   0.765   11    -3.515
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0403         0.490          0.000000    0.0779    0.845
# 1     1       0.0337         0.018          0.107000    0.1760    0.797
# 2     1       0.0380         0.846          0.000004    0.1190    0.908
# 3     0       0.1040         0.706          0.024600    0.0610    0.967
# 4     0       0.1240         0.857          0.000872    0.2130    0.906
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  popularity  \
# 0  185.655       173533               3    32.94975         9           1
# 1  101.801       213613               4    48.82510        10           0
# 2  115.940       223960               4    37.22663        12           0
# 3  105.592       157907               4    24.75484         8           0
# 4  114.617       245600               4    21.79874        14           0
#
#   decade
# 0    60s
# 1    60s
# 2    60s
# 3    60s
# 4    60s

# %%
df.shape
# Out:
# (41099, 20)

# %%
df.isnull().any().sum()
# Out:
# 0

# %%
_ = df.hist(bins=50, figsize=(20, 18))

# %%
scatter_tempo =  df.plot.scatter(x='danceability',
                    y = 'tempo', figsize=(20, 15),
                    colormap='viridis', c='tempo')

# %%
scatter_acousticness = df.plot.scatter(x='danceability',
                    y = 'acousticness', figsize=(20, 15), 
                    colormap='viridis', c='acousticness')

# %%
tempo = [df['tempo'].values]
sns.histplot(tempo, bins=30)
# Out:
# <AxesSubplot:ylabel='Count'>
